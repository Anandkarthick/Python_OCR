# %%
from skimage import data
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
photo_data = misc.imread('patels.jpeg')
photo_data
# Out:
# array([[[192, 169, 135],
#         [191, 168, 134],
#         [190, 167, 133],
#         ...,
#         [207, 191, 178],
#         [209, 193, 180],
#         [212, 196, 183]],
#
#        [[188, 165, 131],
#         [187, 164, 130],
#         [185, 162, 128],
#         ...,
#         [213, 197, 184],
#         [214, 198, 185],
#         [215, 199, 186]],
#
#        [[184, 161, 129],
#         [182, 159, 127],
#         [179, 156, 124],
#         ...,
#         [217, 201, 188],
#         [215, 199, 186],
#         [216, 200, 187]],
#
#        ...,
#        [[200, 186, 173],
#         [200, 186, 173],
#         [200, 186, 173],
#         ...,
#         [219, 195, 161],
#         [218, 194, 160],
#         [217, 193, 159]],
#
#        [[198, 184, 171],
#         [199, 185, 172],
#         [199, 185, 172],
#         ...,
#         [219, 195, 161],
#         [218, 194, 160],
#         [217, 193, 159]],
#
#        [[198, 184, 171],
#         [199, 185, 172],
#         [200, 186, 173],
# ...

# %%
plt.imshow(photo_data)
