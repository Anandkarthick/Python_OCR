# %%
import pytesseract
from PIL import Image
from pytesseract import image_to_string

# %%
image_name = 'dunkin.png'

# %%
print(image_to_string(Image.open('./Picture/'+image_name), lang='eng'))
# Out:
# We1come to Dunkin' Donuts
# Store #334917
# 21-23 Asy1um St., Hartford
# 4f22/2017 7:45:08 AM
#
# Eat In
# 0rder: 807
#
# Register:1 Tran Seq No: 2201807
# Cashier:3andra R.
# *****SALE*****
# 1 12 Bage1s 10.39
# S1iced
# 1 6 Bage1s 6.69
# S1iced
# 2 802 P1a1n 00 7.58
# 1 12 Donuts 9.29
# 1 Ht 001 M0 DRoast 2.02
# 5 Cream
# 2 Sugar
# Sub. Tota1: $36 97
# Tax: $0.13
# Tota1: $36 10
# Discount Tota]: $0.00
# Change $0.00
# American Express: $36.10
#
# American Express
#
# Card Num : XXXXXXXXXXX1007
# Termina1 : 0001
#
# Approva1 : 560238
#
# I agreg to pay the above Tota1 Amount
# accord1ng to Card Issuer Agreement.
#
# Signature:

# %%
 Image.open('./Picture/'+image_name)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1391x3200 at 0x10AFEDD68>

# %%
print(im.size)
# Out:
# (504, 996)

# %%
im.show()

# %%
## reference code.. 

import scipy
from scipy import ndimage
from scipy import misc
import matplotlib.pyplot as plt
from skimage import data

photo_data = misc.imread('./Picture/cvs.png')

blurred_f = ndimage.gaussian_filter(photo_data, 3)

filter_blurred_f = ndimage.gaussian_filter(blurred_f, 1)

alpha = 3 #30
sharpened = blurred_f + alpha * (blurred_f - filter_blurred_f)

plt.figure(figsize=(12, 4))

plt.subplot(131)
plt.imshow(photo_data, cmap=plt.cm.gray)
plt.axis('off')
plt.subplot(132)
plt.imshow(blurred_f, cmap=plt.cm.gray)
plt.axis('off')
plt.subplot(133)
plt.imshow(sharpened, cmap=plt.cm.gray)
plt.axis('off')

plt.tight_layout()
plt.show()
